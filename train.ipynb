# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mlflow

import os
from dotenv import load_dotenv

load_dotenv()

mlflow_uri = os.getenv("MLFLOW_TRACKING_URI")
mlflow_xp_id = 1

mlflow.set_tracking_uri(mlflow_uri)
mlflow.set_experiment(experiment_id=mlflow_xp_id)

sns.set_style("whitegrid")
sns.set_palette("husl")

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
path = os.getenv("DATA_PATH")
df = pd.read_csv(path)

print(f'df shape: {df.shape}')
df.head()
# Out:
# df shape: (5496, 43)
#         dtRef                             idUsuario  qtdeTransacoes  qtdeDias  \
# 0  2024-06-01  000ff655-fa9f-4baa-a108-47f581ec52a1             266        27
# 1  2024-10-01  000ff655-fa9f-4baa-a108-47f581ec52a1             268        28
# 2  2024-04-01  000ff655-fa9f-4baa-a108-47f581ec52a1             188        11
# 3  2024-05-01  000ff655-fa9f-4baa-a108-47f581ec52a1             262        24
# 4  2024-08-01  001749bd-37b5-4b1e-8111-f9fbba90f530               1         1
#
#    mediaTransacoesDias  saldoPontos  qtdePontosPos  qtdePontosNeg  \
# 0             9.851852          635           2635          -2000
# 1             9.571429          686           2686          -2000
# 2            17.090909          275           1275          -1000
# 3            10.916667          484           2484          -2000
# 4             1.000000           50             50              0
#
#    qtdeDiasUltimaTransacao  qtdeDiasPrimeiraTransacao  qtdSkuDistintos  \
# 0                      1.0                       89.0                5
# 1                      4.0                      211.0                5
# 2                      3.0                       28.0                5
# 3                      2.0                       58.0                5
# 4                     21.0                       21.0                1
#
#    qtdeChatMessage  qtdePresença  qtdeTrocaStreamElements  qtdeChurn  \
# 0              235            26                        2          0
# 1              236            27                        2          0
# 2              175            10                        1          0
# 3              234            23                        2          0
# 4                0             1                        0          0
#
#    qtdePonei  qtdeAirflowLover  qtdePresencaStreak  qtdeDailyLoot  qtdeRLover  \
# 0          2                 0                   1              0           0
# 1          2                 0                   1              0           0
# 2          1                 0                   1              0           0
# 3          2                 0                   1              0           0
# 4          0                 0                   0              0           0
#
#    qtdeVendaItemRPG  qtdeTransacoesD7  qtdeDiasD7  saldoPontosD7  \
# 0                 0                 3           2            101
# 1                 0                 2           1             51
# 2                 0                71           5            -87
# 3                 0                13           3           -841
# 4                 0                 0           0              0
#
#    qtdePontosPosD7  qtdePontosNegD7  qtdeTransacoesD14  qtdeDiasD14  \
# 0              101                0                  3            2
# 1               51                0                  2            1
# 2              913            -1000                183            9
# 3              159            -1000                 23            6
# 4                0                0                  0            0
#
#    saldoPontosD14  qtdePontosPosD14  qtdePontosNegD14  qtdeTransacoesD28  \
# 0             101               101                 0                  4
# 1              51                51                 0                  2
# 2             221              1221             -1000                188
# 3            -684               316             -1000                 70
# 4               0                 0                 0                  1
#
#    qtdeDiasD28  saldoPontosD28  qtdePontosPosD28  qtdePontosNegD28  \
# 0            3             151               151                 0
# 1            1              51                51                 0
# 2           11             275              1275             -1000
# 3           11             107              1107             -1000
# 4            1              50                50                 0
#
#    propAvgQtdeTransacoes  propAvgQtdeDias  propAvgMediaTransacoesDias  \
# 0               3.889781         3.278281                    2.135602
# 1               3.309865         2.567615                    2.328737
# 2               3.805468         1.820201                    3.739048
# 3               4.246216         3.255244                    2.322640
# 4               0.013317         0.103973                    0.236635
#
#    propAvgSaldoPontos  propAvgQtdePontosPos  propAvgQtdePontosNeg  flagChurn
# 0            1.516314              4.101926              8.944444          1
# 1            1.288278              2.920954              5.167037          1
# 2            0.798622              2.634551              7.162791          0
# 3            1.275749              4.275765              9.922414          0
# 4            0.104533              0.063302              0.000000          1

# %%
cols = df.columns
for c in cols:
  print(f'{c}: {df[c].dtype}')

df.describe()
# Out:
# dtRef: object
# idUsuario: object
# qtdeTransacoes: int64
# qtdeDias: int64
# mediaTransacoesDias: float64
# saldoPontos: int64
# qtdePontosPos: int64
# qtdePontosNeg: int64
# qtdeDiasUltimaTransacao: float64
# qtdeDiasPrimeiraTransacao: float64
# qtdSkuDistintos: int64
# qtdeChatMessage: int64
# qtdePresença: int64
# qtdeTrocaStreamElements: int64
# qtdeChurn: int64
# qtdePonei: int64
# qtdeAirflowLover: int64
# qtdePresencaStreak: int64
# qtdeDailyLoot: int64
# qtdeRLover: int64
# qtdeVendaItemRPG: int64
# qtdeTransacoesD7: int64
# qtdeDiasD7: int64
# saldoPontosD7: int64
# qtdePontosPosD7: int64
# qtdePontosNegD7: int64
# qtdeTransacoesD14: int64
# qtdeDiasD14: int64
# saldoPontosD14: int64
# qtdePontosPosD14: int64
# qtdePontosNegD14: int64
# qtdeTransacoesD28: int64
# qtdeDiasD28: int64
# saldoPontosD28: int64
# qtdePontosPosD28: int64
# qtdePontosNegD28: int64
# propAvgQtdeTransacoes: float64
# propAvgQtdeDias: float64
# propAvgMediaTransacoesDias: float64
# propAvgSaldoPontos: float64
# propAvgQtdePontosPos: float64
# propAvgQtdePontosNeg: float64
# flagChurn: int64
#        qtdeTransacoes     qtdeDias  mediaTransacoesDias   saldoPontos  \
# count     5496.000000  5496.000000          5496.000000   5496.000000
# mean       204.201055    21.184862             5.206678   1000.646834
# std        992.991116    36.225641             7.720127   2078.516408
# min          1.000000     1.000000             1.000000      1.000000
# 25%          5.000000     2.000000             1.500000    100.000000
# 50%         23.000000     7.000000             3.000000    275.500000
# 75%        102.000000    22.000000             6.000000    993.500000
# max      16633.000000   313.000000           128.903226  31896.000000
#
#        qtdePontosPos  qtdePontosNeg  qtdeDiasUltimaTransacao  \
# count    5496.000000    5496.000000              5496.000000
# mean     2029.110262   -1028.463428                 9.877183
# std      4801.749776    3788.626113                 7.924508
# min         1.000000  -46950.000000                 1.000000
# 25%       100.000000       0.000000                 3.000000
# 50%       301.000000       0.000000                 8.000000
# 75%      1458.250000       0.000000                16.000000
# max     49446.000000       0.000000                27.000000
#
#        qtdeDiasPrimeiraTransacao  qtdSkuDistintos  qtdeChatMessage  \
# count                5496.000000      5496.000000      5496.000000
# mean                   91.027838         2.958879       177.760371
# std                    98.406330         2.256472       967.522700
# min                     1.000000         1.000000         0.000000
# 25%                    19.000000         2.000000         2.000000
# 50%                    50.000000         2.000000        14.000000
# 75%                   132.000000         3.000000        73.000000
# max                   430.000000        21.000000     16320.000000
#
#        qtdePresença  qtdeTrocaStreamElements    qtdeChurn    qtdePonei  \
# count   5496.000000              5496.000000  5496.000000  5496.000000
# mean      18.573872                 0.945415     3.582242     1.216703
# std       33.676246                 3.594243    14.883269     3.525209
# min        0.000000                 0.000000     0.000000     0.000000
# 25%        1.000000                 0.000000     0.000000     0.000000
# 50%        5.000000                 0.000000     0.000000     0.000000
# 75%       19.000000                 0.000000     0.000000     0.000000
# max      295.000000                49.000000   149.000000    38.000000
#
#        qtdeAirflowLover  qtdePresencaStreak  qtdeDailyLoot   qtdeRLover  \
# count       5496.000000         5496.000000    5496.000000  5496.000000
# mean           0.077511            1.338974       0.469614     0.040211
# std            0.667316            4.165972       2.899685     0.344491
# min            0.000000            0.000000       0.000000     0.000000
# 25%            0.000000            0.000000       0.000000     0.000000
# 50%            0.000000            0.000000       0.000000     0.000000
# 75%            0.000000            1.000000       0.000000     0.000000
# max           11.000000           78.000000      51.000000     5.000000
#
#        qtdeVendaItemRPG  qtdeTransacoesD7   qtdeDiasD7  saldoPontosD7  \
# count       5496.000000       5496.000000  5496.000000    5496.000000
# mean           0.192686          7.815320     1.153202      53.549854
# std            1.422358         32.263969     1.547960     232.533761
# min            0.000000          0.000000     0.000000   -4213.000000
# 25%            0.000000          0.000000     0.000000       0.000000
# 50%            0.000000          0.000000     0.000000       0.000000
# 75%            0.000000          4.000000     2.000000      57.000000
# max           31.000000       1224.000000     7.000000    6071.000000
#
#        qtdePontosPosD7  qtdePontosNegD7  qtdeTransacoesD14  qtdeDiasD14  \
# count      5496.000000      5496.000000        5496.000000  5496.000000
# mean         89.621543       -36.071689          15.477256     2.242176
# std         225.695744       223.521851          60.056754     2.739681
# min           0.000000     -5000.000000           0.000000     0.000000
# 25%           0.000000         0.000000           0.000000     0.000000
# 50%           0.000000         0.000000           2.000000     1.000000
# 75%         100.000000         0.000000          10.000000     3.000000
# max        6121.000000         0.000000        2062.000000    14.000000
#
#        saldoPontosD14  qtdePontosPosD14  qtdePontosNegD14  qtdeTransacoesD28  \
# count     5496.000000       5496.000000       5496.000000        5496.000000
# mean       104.883734        177.802038        -72.918304          32.090975
# std        422.181808        406.832830        435.104270         117.816827
# min     -12875.000000          0.000000     -14000.000000           1.000000
# 25%          0.000000          0.000000          0.000000           2.000000
# 50%         50.000000         50.000000          0.000000           6.000000
# 75%        121.000000        154.000000          0.000000          23.000000
# max       6829.000000       9137.000000          0.000000        3541.000000
#
#        qtdeDiasD28  saldoPontosD28  qtdePontosPosD28  qtdePontosNegD28  \
# count  5496.000000     5496.000000       5496.000000       5496.000000
# mean      4.613901      199.708151        366.321870       -166.613719
# std       5.000795      617.568087        700.689038        771.560736
# min       1.000000   -19250.000000          1.000000     -21000.000000
# 25%       1.000000       50.000000         50.000000          0.000000
# 50%       2.000000      100.000000        102.000000          0.000000
# 75%       6.000000      250.000000        342.500000          0.000000
# max      28.000000     7208.000000      12924.000000          0.000000
#
#        propAvgQtdeTransacoes  propAvgQtdeDias  propAvgMediaTransacoesDias  \
# count            5496.000000      5496.000000                 5496.000000
# mean                2.746433         2.170620                    1.207482
# std                12.762084         3.263277                    1.779591
# min                 0.011704         0.083868                    0.212761
# 25%                 0.080967         0.271270                    0.354695
# 50%                 0.360906         0.827364                    0.665904
# 75%                 1.491148         2.567615                    1.385479
# max               204.211280        26.580727                   27.764559
#
#        propAvgSaldoPontos  propAvgQtdePontosPos  propAvgQtdePontosNeg  \
# count         5496.000000           5496.000000           5496.000000
# mean             2.111456              2.502620              3.047129
# std              4.065150              5.336976             10.299649
# min              0.001764              0.000992              0.000000
# 25%              0.201786              0.156949              0.000000
# 50%              0.656862              0.467169              0.000000
# 75%              2.173721              2.070409              0.000000
# max             61.590292             52.438802            166.800000
#
#          flagChurn
# count  5496.000000
# mean      0.470888
# std       0.499197
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
print(df['dtRef'].value_counts().sort_index())

dates = df['dtRef'].value_counts().sort_index()
oot = df[df['dtRef'] == dates.index[-1]].copy()

print(f'oot shape: {oot.shape}')
oot.head()
# Out:
# dtRef
# 2024-03-01    665
# 2024-04-01    528
# 2024-05-01    542
# 2024-06-01    426
# 2024-07-01    422
# 2024-08-01    415
# 2024-09-01    371
# 2024-10-01    349
# 2024-11-01    258
# 2024-12-01    198
# 2025-01-01    194
# 2025-02-01    374
# 2025-03-01    451
# 2025-04-01    303
# Name: count, dtype: int64
# oot shape: (303, 43)
#          dtRef                             idUsuario  qtdeTransacoes  \
# 8   2025-04-01  0033b737-8235-4c0f-9801-dc4ca185af00             445
# 21  2025-04-01  0122142b-464c-414a-9aad-e901f492a1a3              23
# 53  2025-04-01  0287cd05-1efe-4ad9-b235-ea17e5f8ef9c             303
# 61  2025-04-01  02bfd4d9-4dd6-44e5-88b8-2cc08caf3267             338
# 74  2025-04-01  02ebaed5-c07a-4bdd-bb7b-5334d5b25b39             245
#
#     qtdeDias  mediaTransacoesDias  saldoPontos  qtdePontosPos  qtdePontosNeg  \
# 8         25            17.800000         2066           2066              0
# 21         4             5.750000          121            121              0
# 53        45             6.733333         3248           3498           -250
# 61        89             3.797753         3643           7143          -3500
# 74        51             4.803922         3813           3813              0
#
#     qtdeDiasUltimaTransacao  qtdeDiasPrimeiraTransacao  qtdSkuDistintos  \
# 8                       6.0                      197.0                4
# 21                      7.0                       81.0                2
# 53                      1.0                      351.0                5
# 61                      4.0                      333.0                7
# 74                     18.0                      246.0                8
#
#     qtdeChatMessage  qtdePresença  qtdeTrocaStreamElements  qtdeChurn  \
# 8               416            25                        0          0
# 21               21             2                        0          0
# 53              248            43                        0          0
# 61              221            82                        3          0
# 74              181            49                        0         10
#
#     qtdePonei  qtdeAirflowLover  qtdePresencaStreak  qtdeDailyLoot  \
# 8           1                 0                   3              0
# 21          0                 0                   0              0
# 53          4                 0                   7              1
# 61          7                 0                   1              2
# 74          2                 0                   1              0
#
#     qtdeRLover  qtdeVendaItemRPG  qtdeTransacoesD7  qtdeDiasD7  saldoPontosD7  \
# 8            0                 0                 2           1             51
# 21           0                 0                 2           1              2
# 53           0                 0                21           5            464
# 61           0                22                 4           1             53
# 74           0                 2                 0           0              0
#
#     qtdePontosPosD7  qtdePontosNegD7  qtdeTransacoesD14  qtdeDiasD14  \
# 8                51                0                 62            6
# 21                2                0                  2            1
# 53              464                0                 23            6
# 61               53                0                 11            3
# 74                0                0                  0            0
#
#     saldoPontosD14  qtdePontosPosD14  qtdePontosNegD14  qtdeTransacoesD28  \
# 8              455               455                 0                190
# 21               2                 2                 0                  2
# 53             515               515                 0                 25
# 61             158               158                 0                 20
# 74               0                 0                 0                  1
#
#     qtdeDiasD28  saldoPontosD28  qtdePontosPosD28  qtdePontosNegD28  \
# 8            12             976               976                 0
# 21            1               2                 2                 0
# 53            8             615               615                 0
# 61            6             265               265                 0
# 74            1              50                50                 0
#
#     propAvgQtdeTransacoes  propAvgQtdeDias  propAvgMediaTransacoesDias  \
# 8                5.463477         2.123061                    4.501847
# 21               0.282382         0.339690                    1.454248
# 53               3.720076         3.821510                    1.702946
# 61               4.149787         7.558098                    0.960500
# 74               3.007982         4.331045                    1.214973
#
#     propAvgSaldoPontos  propAvgQtdePontosPos  propAvgQtdePontosNeg  flagChurn
# 8             3.989389              2.191048              0.000000          1
# 21            0.233648              0.128324              0.000000          1
# 53            6.271798              3.709722              0.588161          0
# 61            7.034532              7.575342              8.234250          0
# 74            7.362797              4.043788              0.000000          1

# %%
df_train = df[df['dtRef'] != dates.index[-1]].copy()
print(f'train shape: {df_train.shape}')
# Out:
# train shape: (5193, 43)

# %%
feature_cols, target_col = df_train.columns[2: -1], df_train.columns[-1]
X, y = df_train[feature_cols], df_train[target_col]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
  test_size=0.25,
  stratify=y,
  shuffle=True,
  random_state=42, 
  )

print(f'xtrain shape: {X_train.shape}')
print(f'xtest shape: {X_test.shape}')

'''
  - Verifica se as distriuições das variáveis objetivos 
    em treino e teste são semelhanets
  
  - stratify: Garante que as duas amostras tenham a mesma taxa da variáveil resposta
    Operação custosa, fazer com cautela
'''
print(f'train churn rate: {y_train.mean()}')
print(f'test churn rate: {y_test.mean()}')
# Out:
# xtrain shape: (3894, 40)
# xtest shape: (1299, 40)
# train churn rate: 0.4689265536723164
# test churn rate: 0.46882217090069284

# %%
nrows, ncols = 10, 4

fig, axes = plt.subplots(nrows, ncols, figsize=(20, 25))
axes_flat = axes.flatten()

for i in range(nrows):
  for j in range(ncols):
    idx = i * ncols + j
    sns.kdeplot(data=df_train, x=feature_cols[idx], hue=target_col, 
                fill=True, alpha=0.5, ax=axes[i,j])

plt.tight_layout()
plt.show()

# %%
X_train.isna().sum().sort_values(ascending=True)
# Out:
# qtdeTransacoes                0
# qtdeDias                      0
# mediaTransacoesDias           0
# saldoPontos                   0
# qtdePontosPos                 0
# qtdePontosNeg                 0
# qtdeDiasUltimaTransacao       0
# qtdeDiasPrimeiraTransacao     0
# qtdSkuDistintos               0
# qtdeChatMessage               0
# qtdePresença                  0
# qtdeTrocaStreamElements       0
# qtdeChurn                     0
# qtdePonei                     0
# qtdeAirflowLover              0
# qtdePresencaStreak            0
# qtdeDailyLoot                 0
# qtdeRLover                    0
# qtdeVendaItemRPG              0
# qtdeTransacoesD7              0
# qtdeDiasD7                    0
# saldoPontosD7                 0
# qtdePontosPosD7               0
# qtdePontosNegD7               0
# qtdeTransacoesD14             0
# qtdeDiasD14                   0
# saldoPontosD14                0
# qtdePontosPosD14              0
# qtdePontosNegD14              0
# qtdeTransacoesD28             0
# qtdeDiasD28                   0
# saldoPontosD28                0
# qtdePontosPosD28              0
# qtdePontosNegD28              0
# propAvgQtdeTransacoes         0
# propAvgQtdeDias               0
# propAvgMediaTransacoesDias    0
# propAvgSaldoPontos            0
# propAvgQtdePontosPos          0
# propAvgQtdePontosNeg          0
# dtype: int64

# %%
df_bivar = X_train.copy()
df_bivar[target_col] = y_train

agg = df_bivar.groupby(by=target_col).agg(['median', 'mean']).T
agg['diff'] = agg.iloc[:, 0] / agg.iloc[:, 1]
agg.sort_values(by='diff', ascending=False)

agg
# Out:
# flagChurn                                    0           1        diff
# qtdeTransacoes             median    52.000000    8.000000    6.500000
#                            mean     333.275145   49.812158    6.690639
# qtdeDias                   median    13.000000    3.000000    4.333333
#                            mean      29.895551    9.055860    3.301238
# mediaTransacoesDias        median     3.600000    2.069048    1.739931
#                            mean       6.452296    3.951052    1.633058
# saldoPontos                median   559.500000  123.500000    4.530364
#                            mean    1454.945358  439.205915    3.312673
# qtdePontosPos              median   703.000000  127.000000    5.535433
#                            mean    3088.484526  639.183461    4.831922
# qtdePontosNeg              median     0.000000    0.000000         NaN
#                            mean   -1633.539168 -199.977547    8.168613
# qtdeDiasUltimaTransacao    median     4.000000   14.000000    0.285714
#                            mean       6.722437   13.436473    0.500313
# qtdeDiasPrimeiraTransacao  median    63.000000   30.000000    2.100000
#                            mean      98.082205   71.777108    1.366483
# qtdSkuDistintos            median     3.000000    2.000000    1.500000
#                            mean       3.607834    2.177985    1.656501
# qtdeChatMessage            median    34.000000    5.000000    6.800000
#                            mean     294.546422   40.534502    7.266561
# qtdePresença               median    10.000000    2.000000    5.000000
#                            mean      26.278046    7.664294    3.428633
# qtdeTrocaStreamElements    median     0.000000    0.000000         NaN
#                            mean       1.486944    0.169770    8.758579
# qtdeChurn                  median     0.000000    0.000000         NaN
#                            mean       5.657157    0.608981    9.289540
# qtdePonei                  median     0.000000    0.000000         NaN
#                            mean       1.927950    0.316539    6.090720
# qtdeAirflowLover           median     0.000000    0.000000         NaN
#                            mean       0.132012    0.015334    8.609043
# qtdePresencaStreak         median     0.000000    0.000000         NaN
#                            mean       2.076886    0.301752    6.882747
# qtdeDailyLoot              median     0.000000    0.000000         NaN
#                            mean       0.793520    0.127601    6.218747
# qtdeRLover                 median     0.000000    0.000000         NaN
#                            mean       0.070600    0.006572   10.742908
# qtdeVendaItemRPG           median     0.000000    0.000000         NaN
#                            mean       0.301257    0.066265    4.546246
# qtdeTransacoesD7           median     3.000000    0.000000         inf
#                            mean      14.249033    1.771632    8.042885
# qtdeDiasD7                 median     1.000000    0.000000         inf
#                            mean       1.836074    0.388280    4.728731
# saldoPontosD7              median    50.000000    0.000000         inf
#                            mean      92.804642   15.012048    6.182011
# qtdePontosPosD7            median    51.500000    0.000000         inf
#                            mean     160.865571   18.352683    8.765234
# qtdePontosNegD7            median     0.000000    0.000000         NaN
#                            mean     -68.060928   -3.340635   20.373648
# qtdeTransacoesD14          median     6.000000    1.000000    6.000000
#                            mean      28.066731    3.672508    7.642388
# qtdeDiasD14                median     3.000000    1.000000    3.000000
#                            mean       3.511122    0.832421    4.217966
# saldoPontosD14             median   100.000000    1.000000  100.000000
#                            mean     178.765957   31.874042    5.608512
# qtdePontosPosD14           median   106.500000    1.000000  106.500000
#                            mean     319.123308   38.117196    8.372161
# qtdePontosNegD14           median     0.000000    0.000000         NaN
#                            mean    -140.357350   -6.243154   22.481800
# qtdeTransacoesD28          median    14.000000    3.000000    4.666667
#                            mean      56.150870    9.840088    5.706338
# qtdeDiasD28                median     5.000000    1.000000    5.000000
#                            mean       6.818182    2.171413    3.139975
# saldoPontosD28             median   157.000000   51.000000    3.078431
#                            mean     314.264990   96.805586    3.246352
# qtdePontosPosD28           median   212.000000   52.000000    4.076923
#                            mean     620.096228  116.055312    5.343109
# qtdePontosNegD28           median     0.000000    0.000000         NaN
#                            mean    -305.831238  -19.249726   15.887563
# propAvgQtdeTransacoes      median     0.825089    0.132684    6.218439
#                            mean       4.544160    0.685213    6.631745
# propAvgQtdeDias            median     1.617533    0.429018    3.770319
#                            mean       3.114597    0.965312    3.226519
# propAvgMediaTransacoesDias median     0.850474    0.501362    1.696327
#                            mean       1.485953    0.911514    1.630202
# propAvgSaldoPontos         median     1.278931    0.316915    4.035562
#                            mean       3.096451    0.937721    3.302103
# propAvgQtdePontosPos       median     1.062990    0.210085    5.059808
#                            mean       3.875288    0.818724    4.733328
# propAvgQtdePontosNeg       median     0.000000    0.000000         NaN
#                            mean       5.046888    0.590201    8.551127

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dtf = DecisionTreeClassifier(random_state=42, max_depth=5)
dtf.fit(X_train, y_train)

plt.figure(dpi=800, figsize=(10, 10))
_ = plot_tree(
  dtf,
  feature_names=X_train.columns,
  class_names = ["Nao Churn", "Churn"],
  filled=True,
  )
# Out:
# 2026/03/11 21:23:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e9bc90a0537848e89f7e46d050408baa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2026/03/11 21:23:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:23:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:23:44 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run unique-snipe-956 at: http://localhost:5000/#/experiments/1/runs/e9bc90a0537848e89f7e46d050408baa
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
#Feature Importance
dtf = DecisionTreeClassifier(random_state=42)
dtf.fit(X_train, y_train)

importance = pd.Series(dtf.feature_importances_, index=X_train.columns)

fig, ax = plt.subplots(figsize=(8, 12))
sns.barplot(
  x=importance.sort_values(ascending=False).values,
  y=importance.sort_values(ascending=False).index,
  ax=ax
)
ax.set_title("Feature Importance")
ax.set_xlabel("Importance")
plt.tight_layout()
plt.show()
# Out:
# 2026/03/11 21:23:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5e19354ad3ef48eba466e259c294d09d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2026/03/11 21:23:56 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:23:56 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:23:57 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run puzzled-squid-730 at: http://localhost:5000/#/experiments/1/runs/5e19354ad3ef48eba466e259c294d09d
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
importance_sum = (
    importance
    .sort_values(ascending=False)
    .reset_index()
    .rename(columns={'index': 'feature', 0: 'importance'})
)
importance_sum['acumulada'] = importance_sum['importance'].cumsum()
importance_sum
# Out:
#                        feature  importance  acumulada
# 0                  qtdeDiasD14    0.229401   0.229401
# 1              propAvgQtdeDias    0.087688   0.317090
# 2    qtdeDiasPrimeiraTransacao    0.073981   0.391071
# 3      qtdeDiasUltimaTransacao    0.062506   0.453577
# 4        propAvgQtdeTransacoes    0.057460   0.511037
# 5         propAvgQtdePontosPos    0.049005   0.560042
# 6           propAvgSaldoPontos    0.043775   0.603817
# 7   propAvgMediaTransacoesDias    0.036664   0.640481
# 8                  qtdeDiasD28    0.033646   0.674128
# 9               saldoPontosD28    0.031480   0.705607
# 10               qtdePontosPos    0.024598   0.730206
# 11              qtdeTransacoes    0.023321   0.753527
# 12            qtdeTransacoesD7    0.021826   0.775353
# 13                 saldoPontos    0.020623   0.795977
# 14         mediaTransacoesDias    0.019064   0.815040
# 15           qtdeTransacoesD28    0.018084   0.833124
# 16             qtdePontosPosD7    0.017900   0.851024
# 17            qtdePontosPosD28    0.017422   0.868446
# 18                qtdePresença    0.016183   0.884629
# 19                    qtdeDias    0.015824   0.900452
# 20           qtdeTransacoesD14    0.012902   0.913355
# 21              saldoPontosD14    0.012843   0.926197
# 22             qtdeChatMessage    0.011261   0.937459
# 23               saldoPontosD7    0.010828   0.948287
# 24            qtdePontosPosD14    0.010747   0.959034
# 25        propAvgQtdePontosNeg    0.008274   0.967308
# 26             qtdSkuDistintos    0.007510   0.974818
# 27            qtdeVendaItemRPG    0.007183   0.982001
# 28               qtdePontosNeg    0.003532   0.985533
# 29                   qtdeChurn    0.003435   0.988968
# 30          qtdePresencaStreak    0.003384   0.992352
# 31                  qtdeDiasD7    0.002383   0.994735
# 32               qtdeDailyLoot    0.002048   0.996783
# 33     qtdeTrocaStreamElements    0.001663   0.998445
# 34            qtdePontosNegD14    0.000809   0.999254
# 35             qtdePontosNegD7    0.000746   1.000000
# 36                  qtdeRLover    0.000000   1.000000
# 37            qtdeAirflowLover    0.000000   1.000000
# 38                   qtdePonei    0.000000   1.000000
# 39            qtdePontosNegD28    0.000000   1.000000

# %%
selected_features = importance_sum[importance_sum['acumulada'] < 0.95]
feature_list = selected_features['feature'].to_list()

X_train = X_train[feature_list].copy()
X_test = X_test[feature_list].copy()
X_oot = oot[feature_list].copy()

# %%
from sklearn import pipeline
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from feature_engine import discretisation, encoding
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV

tree_discretisation = discretisation.DecisionTreeDiscretiser(
  variables=feature_list, 
  regression=False, #classificacao
  bin_output='bin_number',
  cv=3,
)

ohe = encoding.OneHotEncoder(
  variables=feature_list,
  ignore_format=True,
  )

model = RandomForestClassifier(random_state=42,)

# model = AdaBoostClassifier(
#   random_state=42,
#   learning_rate=1e-3,
# )

grid_params = {
  "n_estimators": [400, 600],
  "max_depth": [50, 200, 600],
  "min_samples_leaf": [20, 50, 100]
}

grid = GridSearchCV(
  estimator=model,
  param_grid=grid_params,
  cv=3,
  scoring="roc_auc",
  verbose=3
)

model_name = model.__class__.__name__
ohe_name = "One Hot"
discretizer_name = "Discretizer"
gs_name = grid.__class__.__name__

# model = LogisticRegression(random_state=42)
model_pipeline = pipeline.Pipeline(
  steps=[
    (discretizer_name, tree_discretisation),
    (ohe_name, ohe),
    (gs_name, grid),
  ],
)

with mlflow.start_run(run_name=model_name):
  mlflow.sklearn.autolog()
  model_pipeline.fit(X_train, y_train)

  predict_proba = model_pipeline.predict_proba(X_train)[:, 1]
  predict = model_pipeline.predict(X_train)

  acc_train = accuracy_score(y_train, predict)
  roc = roc_auc_score(y_train, predict_proba)
  train_curve = roc_curve(y_train, predict_proba)

  test_predict_proba = model_pipeline.predict_proba(X_test)[:, 1]
  test_predict = model_pipeline.predict(X_test)

  acc_test = accuracy_score(y_test, test_predict)
  roc_test = roc_auc_score(y_test, test_predict_proba)
  test_curve = roc_curve(y_test, test_predict_proba)

  oot_predict_proba = model_pipeline.predict_proba(X_oot)[:, 1]
  oot_predict = model_pipeline.predict(X_oot)

  acc_oot = accuracy_score(oot[target_col], oot_predict)
  roc_oot = roc_auc_score(oot[target_col], oot_predict_proba)
  ooc_curve = roc_curve(oot[target_col], oot_predict_proba)

  mlflow.log_metrics({
    "acc_train": acc_train,
    "auc_train": roc,
    "acc_test": acc_test,
    "auc_test": roc_test,
    "acc_oot": acc_oot,
    "auc_oot": roc_oot,
  })
# Out:
# 2026/03/11 21:24:06 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV 1/3] END max_depth=50, min_samples_leaf=20, n_estimators=400;, score=0.797 total time=   1.1s
# [CV 2/3] END max_depth=50, min_samples_leaf=20, n_estimators=400;, score=0.819 total time=   1.1s
# [CV 3/3] END max_depth=50, min_samples_leaf=20, n_estimators=400;, score=0.840 total time=   1.1s
# [CV 1/3] END max_depth=50, min_samples_leaf=20, n_estimators=600;, score=0.797 total time=   1.7s
# [CV 2/3] END max_depth=50, min_samples_leaf=20, n_estimators=600;, score=0.818 total time=   1.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=20, n_estimators=600;, score=0.840 total time=   1.8s
# [CV 1/3] END max_depth=50, min_samples_leaf=50, n_estimators=400;, score=0.795 total time=   1.1s
# [CV 2/3] END max_depth=50, min_samples_leaf=50, n_estimators=400;, score=0.819 total time=   1.1s
# [CV 3/3] END max_depth=50, min_samples_leaf=50, n_estimators=400;, score=0.839 total time=   1.1s
# [CV 1/3] END max_depth=50, min_samples_leaf=50, n_estimators=600;, score=0.796 total time=   1.7s
# [CV 2/3] END max_depth=50, min_samples_leaf=50, n_estimators=600;, score=0.819 total time=   1.5s
# [CV 3/3] END max_depth=50, min_samples_leaf=50, n_estimators=600;, score=0.839 total time=   1.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=100, n_estimators=400;, score=0.795 total time=   1.0s
# [CV 2/3] END max_depth=50, min_samples_leaf=100, n_estimators=400;, score=0.818 total time=   0.9s
# [CV 3/3] END max_depth=50, min_samples_leaf=100, n_estimators=400;, score=0.837 total time=   1.0s
# [CV 1/3] END max_depth=50, min_samples_leaf=100, n_estimators=600;, score=0.794 total time=   1.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=100, n_estimators=600;, score=0.819 total time=   1.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=100, n_estimators=600;, score=0.837 total time=   1.7s
# [CV 1/3] END max_depth=200, min_samples_leaf=20, n_estimators=400;, score=0.797 total time=   1.4s
# [CV 2/3] END max_depth=200, min_samples_leaf=20, n_estimators=400;, score=0.819 total time=   1.3s
# [CV 3/3] END max_depth=200, min_samples_leaf=20, n_estimators=400;, score=0.840 total time=   1.3s
# [CV 1/3] END max_depth=200, min_samples_leaf=20, n_estimators=600;, score=0.797 total time=   2.1s
# [CV 2/3] END max_depth=200, min_samples_leaf=20, n_estimators=600;, score=0.818 total time=   1.9s
# [CV 3/3] END max_depth=200, min_samples_leaf=20, n_estimators=600;, score=0.840 total time=   1.7s
# [CV 1/3] END max_depth=200, min_samples_leaf=50, n_estimators=400;, score=0.795 total time=   1.0s
# [CV 2/3] END max_depth=200, min_samples_leaf=50, n_estimators=400;, score=0.819 total time=   1.0s
# [CV 3/3] END max_depth=200, min_samples_leaf=50, n_estimators=400;, score=0.839 total time=   1.0s
# [CV 1/3] END max_depth=200, min_samples_leaf=50, n_estimators=600;, score=0.796 total time=   1.6s
# [CV 2/3] END max_depth=200, min_samples_leaf=50, n_estimators=600;, score=0.819 total time=   1.8s
# [CV 3/3] END max_depth=200, min_samples_leaf=50, n_estimators=600;, score=0.839 total time=   1.5s
# [CV 1/3] END max_depth=200, min_samples_leaf=100, n_estimators=400;, score=0.795 total time=   1.2s
# [CV 2/3] END max_depth=200, min_samples_leaf=100, n_estimators=400;, score=0.818 total time=   1.7s
# [CV 3/3] END max_depth=200, min_samples_leaf=100, n_estimators=400;, score=0.837 total time=   1.1s
# [CV 1/3] END max_depth=200, min_samples_leaf=100, n_estimators=600;, score=0.794 total time=   1.5s
# [CV 2/3] END max_depth=200, min_samples_leaf=100, n_estimators=600;, score=0.819 total time=   1.3s
# [CV 3/3] END max_depth=200, min_samples_leaf=100, n_estimators=600;, score=0.837 total time=   1.7s
# [CV 1/3] END max_depth=600, min_samples_leaf=20, n_estimators=400;, score=0.797 total time=   1.7s
# [CV 2/3] END max_depth=600, min_samples_leaf=20, n_estimators=400;, score=0.819 total time=   1.1s
# [CV 3/3] END max_depth=600, min_samples_leaf=20, n_estimators=400;, score=0.840 total time=   1.1s
# [CV 1/3] END max_depth=600, min_samples_leaf=20, n_estimators=600;, score=0.797 total time=   2.1s
# [CV 2/3] END max_depth=600, min_samples_leaf=20, n_estimators=600;, score=0.818 total time=   1.7s
# [CV 3/3] END max_depth=600, min_samples_leaf=20, n_estimators=600;, score=0.840 total time=   1.7s
# [CV 1/3] END max_depth=600, min_samples_leaf=50, n_estimators=400;, score=0.795 total time=   1.1s
# [CV 2/3] END max_depth=600, min_samples_leaf=50, n_estimators=400;, score=0.819 total time=   1.0s
# [CV 3/3] END max_depth=600, min_samples_leaf=50, n_estimators=400;, score=0.839 total time=   1.0s
# [CV 1/3] END max_depth=600, min_samples_leaf=50, n_estimators=600;, score=0.796 total time=   1.5s
# [CV 2/3] END max_depth=600, min_samples_leaf=50, n_estimators=600;, score=0.819 total time=   1.4s
# [CV 3/3] END max_depth=600, min_samples_leaf=50, n_estimators=600;, score=0.839 total time=   1.5s
# [CV 1/3] END max_depth=600, min_samples_leaf=100, n_estimators=400;, score=0.795 total time=   0.9s
# [CV 2/3] END max_depth=600, min_samples_leaf=100, n_estimators=400;, score=0.818 total time=   0.8s
# [CV 3/3] END max_depth=600, min_samples_leaf=100, n_estimators=400;, score=0.837 total time=   0.8s
# [CV 1/3] END max_depth=600, min_samples_leaf=100, n_estimators=600;, score=0.794 total time=   1.4s
# [CV 2/3] END max_depth=600, min_samples_leaf=100, n_estimators=600;, score=0.819 total time=   1.3s
# [CV 3/3] END max_depth=600, min_samples_leaf=100, n_estimators=600;, score=0.837 total time=   1.3s
# 2026/03/11 21:25:25 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:25:25 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/03/11 21:25:36 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:25:37 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:25:38 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:25:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:25:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2026/03/11 21:25:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run RandomForestClassifier at: http://localhost:5000/#/experiments/1/runs/ed63776b0c6a4fcaa15b0e2b402e51d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
gs_results = (
  pd
    .DataFrame(grid.cv_results_)
    .sort_values(by="rank_test_score", ascending=True)
  )

print(f"Melhor params: {grid.best_params_}")
print(f"Melhor AUC: {grid.best_score_:.4f}")

gs_results.head()
# Out:
# Melhor params: {'max_depth': 50, 'min_samples_leaf': 20, 'n_estimators': 600}
# Melhor AUC: 0.8183
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1        1.623151      0.046702         0.157717        0.005889
# 7        1.736400      0.158215         0.157858        0.005950
# 13       1.652519      0.169186         0.166515        0.014186
# 6        1.222465      0.011849         0.125716        0.013266
# 12       1.208937      0.271831         0.107882        0.001199
#
#     param_max_depth  param_min_samples_leaf  param_n_estimators  \
# 1                50                      20                 600
# 7               200                      20                 600
# 13              600                      20                 600
# 6               200                      20                 400
# 12              600                      20                 400
#
#                                                params  split0_test_score  \
# 1   {'max_depth': 50, 'min_samples_leaf': 20, 'n_e...           0.796726
# 7   {'max_depth': 200, 'min_samples_leaf': 20, 'n_...           0.796726
# 13  {'max_depth': 600, 'min_samples_leaf': 20, 'n_...           0.796726
# 6   {'max_depth': 200, 'min_samples_leaf': 20, 'n_...           0.796719
# 12  {'max_depth': 600, 'min_samples_leaf': 20, 'n_...           0.796719
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 1            0.818258           0.839952         0.818312        0.017647
# 7            0.818258           0.839952         0.818312        0.017647
# 13           0.818258           0.839952         0.818312        0.017647
# 6            0.818518           0.839618         0.818285        0.017514
# 12           0.818518           0.839618         0.818285        0.017514
#
#     rank_test_score
# 1                 1
# 7                 1
# 13                1
# 6                 4
# 12                4

# %%
plt.figure(figsize=(10, 8))
plt.plot(train_curve[0], train_curve[1], 
  label=f'Train ROC (AUC = {roc:.3f})', 
  linewidth=2)

plt.plot(test_curve[0], test_curve[1], 
  label=f'Test ROC (AUC = {roc_test:.3f})', 
  linewidth=2)

plt.plot(ooc_curve[0], ooc_curve[1], 
  label=f'OOT ROC (AUC = {roc_oot:.3f})', 
  linewidth=2)

plt.plot([0,1], [0,1], '--', color="black")

plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curves - Train vs Test vs OOT', fontsize=14)
plt.legend(loc='lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve,  classification_report

probs = model_pipeline.predict_proba(X_test)[:, 1]

precisions, recalls, thresholds = precision_recall_curve(y_test, probs)
f1s = 2*(precisions * recalls)/(precisions + recalls)

best_f1_idx = np.argmax(f1s)
best_threshold = thresholds[best_f1_idx]
print(f'Optimal threshold: {best_threshold}')
# Out:
# 2026/03/11 21:25:40 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Optimal threshold: 0.34723449750924623

# %%
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions[:-1], label="Precisions")
plt.plot(thresholds, recalls[:-1], label="Recalls")
plt.plot(thresholds, f1s[:-1], label="F1 Score")
plt.axvline(x=best_threshold, color="red", label="Best Threshold")

plt.legend()
plt.xlabel("Thresholds")
plt.title("Precision x Recall x F1")
# Out:
# Text(0.5, 1.0, 'Precision x Recall x F1')

# %%
oot_proba = model_pipeline.predict_proba(X_oot)[:, 1]
oot_pred_threshold = (oot_proba >= best_threshold).astype(int)
print(classification_report(oot[target_col], oot_pred_threshold))
# Out:
# 2026/03/11 21:25:41 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/reidner/dev/portfolio/ml@tmw_churn/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
#               precision    recall  f1-score   support
#
#            0       0.86      0.59      0.70       150
#            1       0.69      0.91      0.79       153
#
#     accuracy                           0.75       303
#    macro avg       0.78      0.75      0.74       303
# weighted avg       0.78      0.75      0.74       303
